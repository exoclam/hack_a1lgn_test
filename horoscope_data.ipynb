# %% [markdown]
# This is based on Nazar Budaiev and Micah Oeur's CodeAstro project: https://github.com/nbudaiev/exo_horoscope

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

path = "~/Desktop/hack_al1gn/"
data = pd.read_csv(path+'data/cumulative_2025.03.09_15.21.04.csv')
data.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  ...  \
# 0      1.000              0              0              0              0  ...
# 1      0.969              0              0              0              0  ...
# 2      0.000              0              0              0              0  ...
# 3      0.000              0              1              0              0  ...
# 4      1.000              0              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
data_trim = data[['kepid','kepler_name','koi_period','koi_prad','koi_teq','koi_insol','koi_steff','koi_slogg','koi_srad','ra','dec','koi_kepmag']].dropna(subset='kepler_name')
data_trim
# Out:
#          kepid    kepler_name  koi_period  koi_prad  koi_teq  koi_insol  \
# 0     10797460   Kepler-227 b    9.488036      2.26    793.0      93.59
# 1     10797460   Kepler-227 c   54.418383      2.83    443.0       9.11
# 4     10854555   Kepler-664 b    2.525592      2.75   1406.0     926.16
# 5     10872983   Kepler-228 d   11.094321      3.90    835.0     114.81
# 6     10872983   Kepler-228 c    4.134435      2.77   1160.0     427.65
# ...        ...            ...         ...       ...      ...        ...
# 8817   7350067  Kepler-1646 b    4.485592      0.95    365.0       4.20
# 8956   9730163   Kepler-445 d    8.152759      2.44    305.0       2.03
# 9014   8311864   Kepler-452 b  384.847556      1.09    220.0       0.56
# 9083   7935997  Kepler-1629 b    3.875943      0.68   1081.0     323.21
# 9181   8873450  Kepler-1975 b   24.278380      2.03    432.0       8.27
#
#       koi_steff  koi_slogg  koi_srad         ra        dec  koi_kepmag
# ...

# %%
plt.hist2d(data_trim['ra'], data_trim['dec'])
plt.xlabel('ra [degrees]')
plt.ylabel('dec [degrees]')
plt.colorbar(label='count')
plt.show()

# %% [markdown]
# Assign systems to users based on their multiplicity (siblings or not), birth month (eccentricity), birth year (stellar age), and birth lat/lon (RA/Dec).

# %%
class User(object):
    """
    User class
    """

    def __init__(self, user, year, month, lat, lon, siblings):
        """
        Args:
            user (str): User's name in the form 'User'
            year (int): Birthyear of User
            month (int): Birthmonth of User
            lat (float): Birth latitude of User
            lon (float): Birth longitude of User
            siblings (int): Number of siblings
        """

        self.user = user

        self.year = year
        self.month = month
        self.lat = lat
        self.lon = lon
        self.siblings = siblings

    def map_lat_lon_ra_dec(lat, lon):
        
        return ra, dec
